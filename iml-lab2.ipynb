# %%
#Name:- Makvana ranju 
#Enroll: 216270307105
#practical no.2: Write a NumPy program to implement following operation
# to convert a list of numeric values into a one-dimensional NumPy array

import numpy as np # linear algebra
a = np.array([1,2,3,4,5,6])
print(a)
print(a.dtype)

# %%
#Name:- Makvana ranju 
#Enroll: 216270307105
# Practical No.2: Write a NumPy program to implement following operation
# to create a 3x3 matrix with values ranging from 2 to 10
import numpy as np
a = np.array([[[2,3,4],[5,6,7],[8,7,6]]])
print(a)

# %%
# Makvana ranju
# Enroll: 216270307105

# Practical No.2: Write a NumPy program to implement following operation
#  to append values at the end of an array
import numpy as np
a = np.array([1,2,3,4,5,6])
b=np.append(a,7)
print(b)

# %%
#Makvana ranju 
# Enroll:216270307105
# Practical No.2: Write a NumPy program to implement following operation
# to create another shape from an array without changing its data (3*2 to 2*3)
a = np.array([1,2,3,4,5,6])
print("Original a: ", a)

b = a.reshape(3, 2)
print("\nNew b of shape 3x2:\n", b)

b = a.reshape(2, 3)
print("\nNew b of shape 2x3:\n", b)

# %%
# Makvana ranju
# Enroll: 216270307105

# Practical No:5Write a NumPy program to implement following operation
#• to find the maximum and minimum value of a given flattened array
#• to compute the mean, standard deviation,and variance of a given array along the second axis
import numpy as np
a = np.array([[1,2,3],[4,5,6]])
print("a: \n", a)

b = a.flatten()
print("\nFlatten a row-major order: \n", b)
print("main(b): ", min(b))
print("max(b): ", max(b))
